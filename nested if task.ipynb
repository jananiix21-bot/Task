# %%
# Smart ATM Login

input=int(input("Enter ATM PIN: "))
input=int("Enter Withdrawal Amount: "))

if pin == 7777:
    if amount >= 100 and amount <= 5000:
        print("Transaction Successful")
    else:
        print("Invalid Withdrawal Amount")
else:
    print("Invalid PIN")
# Out:
# Enter ATM PIN:  7777
# Enter Withdrawal Amount:  7777
# Invalid PIN

# %%
# Mobile unlock system

password = str(input("Enter Password:"))python123
battery_percentage = (int(input("enter battery_percentage:"))

if password == "python123":
    if battery_percentage >=20:
        print("mobile unlocked")
    else:
        print("low battery")
else:
    print("wrong password")
# Out:
#   Cell In[10], line 4
#     battery_percentage = (int(input("enter battery_percentage:"))
#                          ^
# SyntaxError: '(' was never closed

# %%
# Mobile unlock system

password = input("Enter Password:")
battery_percentage = int(input("Enter battery_percentage:"))

if password == "python123":
    if battery_percentage >= 20:
        print("mobile unlocked")
    else:
        print("low battery")
else:
    print("wrong password")
# Out:
# Enter Password:  python123
# Enter battery_percentage:  50
# mobile unlocked

# %%
# online movie ticket

age= int(input("enter age:"))
ticket_amount= int(input("enter ticket amount"))

if age >=5 and age <=100:
    if ticket_amount <=500:
        print("ticket booked")
    else:
        print("insufficient budget")
else:
    print("invalid age")
# Out:
# enter age: 30
# enter ticket amount 280
# ticket booked

# %%
#employee bonus checker

experience= int(input("enter years of experience"))
salary= int(input("enter salary"))

if experience >=1 and experience <=40:
    if salary <=50000:
        print("eligible for bonus")
    else:
        print("not eligible for bonus")
else:
    print("invalid experience")
# Out:
# enter years of experience 7
# enter salary 70000
# not eligible for bonus

# %%
#Student Scholarship System 

student_name= input("student name")
marks=int(input("marks"))
attendance_Percentage = int(input("attendance Percentage "))

if marks >=0 and marks <=80:
    if marks >=80:
        if attendance_percentage >=75:
            print("Scholarship Approved")
        else:
            print("Attendance Too Low")       
    else:    
        print("Marks Not Enough")
else:
    print("invalid marks")
# Out:
# student name Janani
# marks 77
# attendance Percentage  90
# Marks Not Enough
